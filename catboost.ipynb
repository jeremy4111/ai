# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
SEED = 1
data_train = pd.read_excel("train_processed.xlsx")
data_test =pd.read_excel("01test.xlsx")
data_train.head() # Show data (看看是否讀取成功)
# Out:
#    手機螢幕溫度(平均)  手機螢幕溫度(最大)  手機背蓋溫度(平均)  平均APP運作指標/小時    充電時間指標    手機電池電量  \
# 0   -2.600452   -2.833071   -3.553067     -0.984729 -0.820966 -5.324059
# 1   -2.606880   -2.838397   -3.544191     -0.984776  2.337184 -5.283197
# 2   -2.628558   -2.857238   -3.556987     -0.984526  0.042620 -5.313652
# 3   -2.627114   -2.852910   -3.541104     -0.984609 -0.586660 -5.333278
# 4   -2.618020   -2.845929   -3.547520     -0.984577 -0.669485 -5.323154
#
#    CPU跑分階級  手機外殼/包膜指標    外型平均曲率    上網頻率指標    通話頻率指標  新機/二手/老舊    內容容量比率  \
# 0        3  -0.741141  3.593824 -1.395510 -1.225014 -0.494159  0.750427
# 1        4  -0.603315  4.295257 -1.395792 -1.225314 -0.494159  0.479721
# 2        3  -0.286121  3.844972 -1.395733 -1.225263 -0.494159  0.754607
# 3        3  -0.070108  3.763350 -1.395879 -1.225406 -0.494159  0.306494
# 4        3  -0.448527  3.619669 -1.395727 -1.225276 -0.494159  0.237039
#
#     CPU效能等級  Underclocking
# 0 -1.955921              0
# 1 -1.463128              1
# 2 -1.955921              0
# 3 -1.955921              1
# 4 -1.955921              0

# %%
data_test.describe()
# Out:
#                 id   手機螢幕溫度(平均)   手機螢幕溫度(最大)   手機背蓋溫度(平均)  平均APP運作指標/小時  \
# count  1777.000000  1777.000000  1777.000000  1777.000000   1777.000000
# mean    889.000000    39.383808    45.662299    51.778120    663.176020
# std     513.120031    14.856589    15.842336    14.473741    673.408149
# min       1.000000     8.296961     8.595238     2.562656      5.568486
# 25%     445.000000    28.533183    35.000000    43.513333    231.100000
# 50%     889.000000    39.714286    46.952381    53.286667    426.500000
# 75%    1333.000000    50.571429    58.238095    60.988103    874.700000
# max    1777.000000    75.619048    79.428571   118.066667   4412.000000
#
#             充電時間指標       手機電池電量      CPU跑分階級    手機外殼/包膜指標       外型平均曲率  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      0.227270    75.154126     3.323016     0.109873     0.008854
# std       0.227092    14.066583     0.676416     0.100905     0.121857
# min       0.000000    47.474747     3.000000     0.001798    -1.043000
# 25%       0.032967    62.807622     3.000000     0.057870    -0.055600
# 50%       0.155779    76.875902     3.000000     0.084313     0.006867
# 75%       0.373913    86.417749     3.000000     0.143811     0.069451
# max       0.966667    99.909812     6.000000     1.479609     1.208233
#
#             上網頻率指標       通話頻率指標     新機/二手/老舊       內容容量比率      CPU效能等級
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean   2564.871316  2225.209257     0.283624     0.863548     1.323016
# std    1837.430356  1815.895616     0.573953     0.180826     0.676416
# min       0.812024     0.000000     0.000000     0.000000     1.000000
# 25%    1001.000000   618.791051     0.000000     0.809392     1.000000
# 50%    2292.190025  1920.000000     0.000000     0.933114     1.000000
# 75%    3840.000000  3482.000000     0.000000     0.986112     1.000000
# max    8683.000000  8476.000000     5.000000     1.000000     4.000000

# %%
y_data = data_train['Underclocking']
feature_ex =['手機螢幕溫度(平均)', '手機背蓋溫度(平均)', '充電時間指標', '手機電池電量', 'CPU跑分階級', '上網頻率指標', '通話頻率指標', '內容容量比率']
x_data = data_train[feature_ex]


# 正規化：將數據縮放到0和1之間
x_data_normalized = (x_data - x_data.min()) / (x_data.max() - x_data.min())
print("Normalized Data:")
print(x_data_normalized)

# 標準化：將數據轉換為均值為0，標準差為1的分佈
x_data_standardized = (x_data - x_data.mean()) / x_data.std()
print("\nStandardized Data:")
print(x_data_standardized)

# 先正規化後標準化
x_data = (x_data_normalized - x_data_normalized.mean()) / x_data_normalized.std()
print("\nNormalized then Standardized Data:")
print(x_data)
# Out:
# Normalized Data:
#       手機螢幕溫度(平均)  手機背蓋溫度(平均)    充電時間指標    手機電池電量   CPU跑分階級    上網頻率指標  \
# 0       0.751415    0.351942  0.040835  0.256490  0.000000  0.741359
# 1       0.656482    0.480422  0.758026  0.834848  0.333333  0.208022
# 2       0.336291    0.295218  0.236949  0.403789  0.000000  0.318551
# 3       0.357618    0.525096  0.094044  0.125995  0.000000  0.043074
# 4       0.491931    0.432228  0.075235  0.269297  0.000000  0.330148
# ...          ...         ...       ...       ...       ...       ...
# 3796    0.171056    0.486771  0.023781  0.103842  1.000000  0.037259
# 3797    0.926866    0.295897  0.401126  0.095881  0.000000  0.500673
# 3798    0.165149    0.338263  0.272232  0.099342  0.000000  0.011647
# 3799    0.482086    0.479499  0.328249  0.618553  0.000000  0.426589
# 3800    0.739812    0.446946  0.025231  0.726203  0.333333  0.596876
#
#         通話頻率指標    內容容量比率
# 0     0.741666  0.999200
# 1     0.174929  0.947380
# 2     0.270737  1.000000
# 3     0.000000  0.914220
# 4     0.246156  0.900924
# ...        ...       ...
# 3796  0.012880  0.975253
# 3797  0.471768  0.959816
# 3798  0.000000  0.883101
# 3799  0.399803  0.713428
# 3800  0.594661  0.915503
#
# [3801 rows x 8 columns]
#
# Standardized Data:
#       手機螢幕溫度(平均)  手機背蓋溫度(平均)    充電時間指標    手機電池電量   CPU跑分階級    上網頻率指標  \
# 0       1.362827   -0.615541 -0.801396 -0.993421 -0.446202  2.132808
# 1       0.920875    0.435311  2.193225  1.158640  1.038924 -0.416053
# 2      -0.569740   -1.079488  0.017474 -0.445324 -0.446202  0.112176
# 3      -0.470454    0.800702 -0.579223 -1.478991 -0.446202 -1.204353
# 4       0.154826    0.041124 -0.657758 -0.945765 -0.446202  0.167599
# ...          ...         ...       ...       ...       ...       ...
# 3796   -1.338972    0.487240 -0.872603 -1.561422  4.009174 -1.232143
# 3797    2.179620   -1.073931  0.702994 -1.591046 -0.446202  0.982553
# 3798   -1.366471   -0.727424  0.164800 -1.578166 -0.446202 -1.354545
# 3799    0.108994    0.427758  0.398698  0.353811 -0.446202  0.628497
# 3800    1.308811    0.161504 -0.866549  0.754374  1.038924  1.442314
#
#         通話頻率指標    內容容量比率
# 0     2.237203  0.782335
# 1    -0.410956  0.498360
# 2     0.036722  0.786720
# 3    -1.228338  0.316642
# 4    -0.078139  0.243783
# ...        ...       ...
# 3796 -1.168155  0.651108
# 3797  0.976066  0.566509
# 3798 -1.228338  0.146111
# 3799  0.639801 -0.783706
# 3800  1.550303  0.323673
#
# [3801 rows x 8 columns]
#
# Normalized then Standardized Data:
#       手機螢幕溫度(平均)  手機背蓋溫度(平均)    充電時間指標    手機電池電量   CPU跑分階級    上網頻率指標  \
# 0       1.362827   -0.615541 -0.801396 -0.993421 -0.446202  2.132808
# 1       0.920875    0.435311  2.193225  1.158640  1.038924 -0.416053
# 2      -0.569740   -1.079488  0.017474 -0.445324 -0.446202  0.112176
# 3      -0.470454    0.800702 -0.579223 -1.478991 -0.446202 -1.204353
# 4       0.154826    0.041124 -0.657758 -0.945765 -0.446202  0.167599
# ...          ...         ...       ...       ...       ...       ...
# 3796   -1.338972    0.487240 -0.872603 -1.561422  4.009174 -1.232143
# 3797    2.179620   -1.073931  0.702994 -1.591046 -0.446202  0.982553
# 3798   -1.366471   -0.727424  0.164800 -1.578166 -0.446202 -1.354545
# 3799    0.108994    0.427758  0.398698  0.353811 -0.446202  0.628497
# 3800    1.308811    0.161504 -0.866549  0.754374  1.038924  1.442314
#
#         通話頻率指標    內容容量比率
# 0     2.237203  0.782335
# 1    -0.410956  0.498360
# 2     0.036722  0.786720
# 3    -1.228338  0.316642
# 4    -0.078139  0.243783
# ...        ...       ...
# 3796 -1.168155  0.651108
# 3797  0.976066  0.566509
# 3798 -1.228338  0.146111
# 3799  0.639801 -0.783706
# 3800  1.550303  0.323673
#
# [3801 rows x 8 columns]

# %%
#TomekLinks
from sklearn.preprocessing import MinMaxScaler, StandardScaler 
from collections import Counter
from imblearn.under_sampling import TomekLinks
print('Original dataset shape %s' % Counter(y_data))
tl = TomekLinks()
x_data, y_data = tl.fit_resample(x_data, y_data)
print('Resampled dataset shape %s' % Counter(y_data))
# Out:
# Original dataset shape Counter({0: 2170, 1: 1631})
# Resampled dataset shape Counter({0: 1822, 1: 1631})

# %%
ex =['手機螢幕溫度(平均)', '手機背蓋溫度(平均)', '充電時間指標', '手機電池電量', 'CPU跑分階級', '上網頻率指標', '通話頻率指標', '內容容量比率']
for feature in ex:
    x_data[feature] = x_data[feature].astype(str)
y_data =y_data.astype(str)

# %%
from sklearn.model_selection import train_test_split

trainX, testX, trainY, testY = train_test_split(x_data, y_data, test_size=0.3, random_state=42)

# %%
#pool-catboostData處理方式
cat_features = list(range(x_data.shape[1]))
print(cat_features)
from catboost import Pool
train_data = Pool(data=trainX,
                  label=trainY,
                  cat_features=cat_features
                 )
valid_data = Pool(data=testX,
                  label=testY,
                  cat_features=cat_features
                 )
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score
SEED = 1
#monotone_constraints = [1,1,1,-1,0,0,0,0]
params = {'loss_function':'Logloss',
          'eval_metric':'Accuracy',
          'early_stopping_rounds': 2000,
          'learning_rate':0.09,
          'depth':3,
          'l2_leaf_reg':5,
          'boosting_type':'Ordered',#Plain，Ordered
          'boost_from_average':True,
          'langevin':True,
          'score_function':'NewtonCosine',#'NewtonCosine'
          'allow_const_label':True,
          'penalties_coefficient':0.5,
          'sampling_frequency':'PerTree',
          #'monotone_constraints':monotone_constraints, 
          'bootstrap_type':'Bernoulli',
          'subsample':0.66,
          #'bagging_temperature':100,
        'random_seed':SEED,
          
         #'random_strength':1.5,
          
          #'rsm':0.5,
        #'sampling_frequency':"PerTree",#"PerTree"
        #'bagging_temperature':0.2,
        #'scale_pos_weight':1,
        #'max_leaves':64,
        #'min_data_in_leaf':2,
        'feature_weights': "手機螢幕溫度(平均):0.9,手機背蓋溫度(平均):0.14,充電時間指標:0.06,手機電池電量:0.02,CPU跑分階級:0.09,上網頻率指標:0.12,通話頻率指標:0.1,內容容量比率:3",
        'task_type':'GPU',
        'verbose': 50,
         
         }
cbc = CatBoostClassifier(**params)
cbc.fit(train_data, # instead of X_train, y_train
          eval_set=valid_data, # instead of (X_valid, y_valid)
          use_best_model=True, 
          plot=True
         );
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.5262722	test: 0.5308880	best: 0.5308880 (0)	total: 21.6ms	remaining: 21.5s
# 50:	learn: 0.6379810	test: 0.6650579	best: 0.6650579 (43)	total: 1.07s	remaining: 19.9s
# 100:	learn: 0.6532892	test: 0.6621622	best: 0.6650579 (43)	total: 2.14s	remaining: 19.1s
# 150:	learn: 0.6545304	test: 0.6631274	best: 0.6650579 (43)	total: 3.16s	remaining: 17.8s
# 200:	learn: 0.6541167	test: 0.6631274	best: 0.6650579 (43)	total: 4.26s	remaining: 16.9s
# 250:	learn: 0.6549441	test: 0.6631274	best: 0.6650579 (43)	total: 5.31s	remaining: 15.8s
# 300:	learn: 0.6545304	test: 0.6631274	best: 0.6650579 (43)	total: 6.31s	remaining: 14.7s
# 350:	learn: 0.6537029	test: 0.6650579	best: 0.6650579 (43)	total: 7.33s	remaining: 13.5s
# 400:	learn: 0.6574266	test: 0.6640927	best: 0.6650579 (43)	total: 8.32s	remaining: 12.4s
# 450:	learn: 0.6619777	test: 0.6640927	best: 0.6660232 (411)	total: 9.33s	remaining: 11.4s
# 500:	learn: 0.6623914	test: 0.6602317	best: 0.6660232 (411)	total: 10.3s	remaining: 10.3s
# 550:	learn: 0.6636326	test: 0.6534749	best: 0.6660232 (411)	total: 11.4s	remaining: 9.28s
# 600:	learn: 0.6648738	test: 0.6389961	best: 0.6660232 (411)	total: 12.4s	remaining: 8.26s
# 650:	learn: 0.6640463	test: 0.6515444	best: 0.6660232 (411)	total: 13.5s	remaining: 7.24s
# 700:	learn: 0.6665288	test: 0.6418919	best: 0.6660232 (411)	total: 14.6s	remaining: 6.21s
# 750:	learn: 0.6690112	test: 0.6476834	best: 0.6660232 (411)	total: 15.5s	remaining: 5.15s
# 800:	learn: 0.6706661	test: 0.6457529	best: 0.6660232 (411)	total: 16.5s	remaining: 4.11s
# 850:	learn: 0.6719073	test: 0.6428571	best: 0.6660232 (411)	total: 17.5s	remaining: 3.07s
# 900:	learn: 0.6719073	test: 0.6418919	best: 0.6660232 (411)	total: 18.6s	remaining: 2.04s
# 950:	learn: 0.6719073	test: 0.6428571	best: 0.6660232 (411)	total: 19.6s	remaining: 1.01s
# 999:	learn: 0.6719073	test: 0.6418919	best: 0.6660232 (411)	total: 20.6s	remaining: 0us
# bestTest = 0.666023166
# bestIteration = 411
# Shrink model to first 412 iterations.

# %%
#CV
from catboost import cv

params = {'loss_function':'Logloss',
          'eval_metric':'Accuracy',
          'verbose': 200,
          'random_seed': SEED
         }

all_train_data = Pool(data=x_data_normalized_then_standardized,
                      label=y_data,
                      cat_features=cat_features
                     )

scores = cv(pool=all_train_data,
            params=params, 
            fold_count=4,
            seed=SEED, 
            shuffle=True,
            stratified=True, # if True the folds are made by preserving the percentage of samples for each class
            plot=True
           )

# %%
cbc.get_feature_importance(prettified=True)

# %%
# 读取测试数据
data_test = pd.read_excel("01test.xlsx")

for feature in feature_ex:
    data_test[feature] = data_test[feature].astype(str)
    
test_id = data_test.pop('id')  
data_test=data_test[feature_ex]
# 使用xgboost模型进行预测
predicted_ans = cbc_4.predict(data_test)  # 确保这里使用的是正确处理后的测试数据

# 创建提交DataFrame
my_submission = pd.DataFrame({'id': test_id, 'Underclocking': predicted_ans})
my_submission.to_csv('submission.csv', index=False)
